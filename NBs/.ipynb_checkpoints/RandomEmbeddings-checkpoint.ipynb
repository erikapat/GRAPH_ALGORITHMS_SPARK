# %% [markdown]
# #### PRUEBAS: Embedding generator

# %%
import os
#os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages graphframes:graphframes:0.6.0-spark2.3-s_2.11 pyspark-shell'
os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages graphframes:graphframes:0.7.0-spark2.3-s_2.11 pyspark-shell'
#os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages graphframes:graphframes:0.8.0-spark3.0-s_2.12 pyspark-shell'

import pyspark
from pyspark.sql import *
from pyspark.sql.functions import udf
import matplotlib.pyplot as plt

# %%
os.environ.get("SPARK_HOME") is not None
# Out:
# False

# %%
import sys  
#sys.path.insert(0, 'utils_merc')
from utils_merc.Embeddings import *
from utils_merc.Plot import *

# %%
E = Embeddings(dimension = 30, num_elements = 15)

# %%
Plot.corrplot(E.as_numpy(), precision = 1)
# Out:
# <style  type="text/css" >
#     #T_3f3d5f00_b3e3_11ea_93b8_acde48001122row0_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_3f3d5f00_b3e3_11ea_93b8_acde48001122row0_col1 {
#             background-color:  #d7e6f5;
#             color:  #000000;
#         }    #T_3f3d5f00_b3e3_11ea_93b8_acde48001122row0_col2 {
#             background-color:  #7ab6d9;
#             color:  #000000;
#         }    #T_3f3d5f00_b3e3_11ea_93b8_acde48001122row0_col3 {
#             background-color:  #b7d4ea;
#             color:  #000000;
#         }    #T_3f3d5f00_b3e3_11ea_93b8_acde48001122row0_col4 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_3f3d5f00_b3e3_11ea_93b8_acde48001122row0_col5 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_3f3d5f00_b3e3_11ea_93b8_acde48001122row0_col6 {
#             background-color:  #e0ecf8;
#             color:  #000000;
# ...
